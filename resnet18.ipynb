# %%
from __future__ import print_function

import numpy as np
import warnings
import tensorflow

# %env KERAS_BACKEND=tensorflow
from keras.callbacks import LearningRateScheduler
import keras
from keras.layers import Input
from keras import layers
from keras.layers import Dense
from keras.layers import Activation
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers import ZeroPadding2D
from keras.layers import AveragePooling2D
from keras.layers import GlobalAveragePooling2D
from keras.layers import BatchNormalization
from keras.models import Model
from keras.preprocessing import image
import keras.backend as K
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import decode_predictions
from keras.applications.imagenet_utils import preprocess_input
from keras.engine.topology import get_source_inputs
# Out:
# env: KERAS_BACKEND=tensorflow

# %%
def conv2d_bn(x, filters, kernel_size, weight_decay=.0, strides=(1, 1)):
    layer = Conv2D(filters=filters,
                   kernel_size=kernel_size,
                   strides=strides,
                   padding='same',
                   use_bias=False,
                   kernel_regularizer=l2(weight_decay)
                   )(x)
    layer = BatchNormalization()(layer)
    return layer

# %%
def conv2d_bn_relu(x, filters, kernel_size, weight_decay=.0, strides=(1, 1)):
    layer = conv2d_bn(x, filters, kernel_size, weight_decay, strides)
    layer = Activation('relu')(layer)
    return layer

# %%
def ResidualBlock(x, filters, kernel_size, weight_decay, downsample=True):
    if downsample:
        # residual_x = conv2d_bn_relu(x, filters, kernel_size=1, strides=2)
        residual_x = conv2d_bn(x, filters, kernel_size=1, strides=2)
        stride = 2
    else:
        residual_x = x
        stride = 1
    residual = conv2d_bn_relu(x,
                              filters=filters,
                              kernel_size=kernel_size,
                              weight_decay=weight_decay,
                              strides=stride,
                              )
    residual = conv2d_bn(residual,
                         filters=filters,
                         kernel_size=kernel_size,
                         weight_decay=weight_decay,
                         strides=1,
                         )
    out = layers.add([residual_x, residual])
    out = Activation('relu')(out)
    return out

# %%
def ResNet18(classes, input_shape, weight_decay=1e-4):
    input = Input(shape=input_shape)
    x = input
    # x = conv2d_bn_relu(x, filters=64, kernel_size=(7, 7), weight_decay=weight_decay, strides=(2, 2))
    # x = MaxPool2D(pool_size=(3, 3), strides=(2, 2),  padding='same')(x)
    x = conv2d_bn_relu(x, filters=64, kernel_size=(3, 3), weight_decay=weight_decay, strides=(1, 1))

    # # conv 2
    x = ResidualBlock(x, filters=64, kernel_size=(3, 3), weight_decay=weight_decay, downsample=False)
    x = ResidualBlock(x, filters=64, kernel_size=(3, 3), weight_decay=weight_decay, downsample=False)
    # # conv 3
    x = ResidualBlock(x, filters=128, kernel_size=(3, 3), weight_decay=weight_decay, downsample=True)
    x = ResidualBlock(x, filters=128, kernel_size=(3, 3), weight_decay=weight_decay, downsample=False)
    # # conv 4
    x = ResidualBlock(x, filters=256, kernel_size=(3, 3), weight_decay=weight_decay, downsample=True)
    x = ResidualBlock(x, filters=256, kernel_size=(3, 3), weight_decay=weight_decay, downsample=False)
    # # conv 5
    x = ResidualBlock(x, filters=512, kernel_size=(3, 3), weight_decay=weight_decay, downsample=True)
    x = ResidualBlock(x, filters=512, kernel_size=(3, 3), weight_decay=weight_decay, downsample=False)
    x = AveragePooling2D(pool_size=(4, 4), padding='valid')(x)
    x = Flatten()(x)
    x = Dense(classes, activation='softmax')(x)
    model = Model(input, x, name='ResNet18')
    return model

# %%
from keras.datasets import cifar10


(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
mean_image = np.mean(x_train, axis=0)
x_train -= mean_image
x_test -= mean_image
x_train = x_train/128
x_test = x_test/128 
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
from keras.callbacks import ReduceLROnPlateau, CSVLogger, EarlyStopping
from keras.regularizers import l2
from keras.utils.vis_utils import plot_model

batch_size = 128

nb_epoch = 200
data_augmentation = True
lr_schedule = [40,60,70] # epoch_step
def schedule(epoch_idx):
    if (epoch_idx + 1) < lr_schedule[0]:
        return 0.001 
    if (epoch_idx + 1) < lr_schedule[1]:
        return 0.0001
    if (epoch_idx + 1) < lr_schedule[2]:
        return 0.001
    return 0.0001
  
   
weight_decay = 1e-4
lr = 1e-1
num_classes = 10
resnet18 = ResNet18(input_shape=(32, 32, 3), classes=num_classes, weight_decay=weight_decay)
#opt = optimizers.SGD(lr=lr, momentum=0.9, nesterov=False)
resnet18.compile(optimizer='Adam',
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
resnet18.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "ResNet18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 32, 32, 64)   1728        input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 32, 32, 64)   256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 32, 32, 64)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 32, 32, 64)   36864       activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 32, 32, 64)   256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 32, 32, 64)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 32, 32, 64)   36864       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 32, 32, 64)   256         conv2d_43[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 32, 32, 64)   0           activation_35[0][0]
#                                                                  batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 32, 32, 64)   0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 32, 64)   36864       activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 32, 32, 64)   256         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 32, 32, 64)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 64)   36864       activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 32, 32, 64)   256         conv2d_45[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 32, 32, 64)   0           activation_37[0][0]
#                                                                  batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 64)   0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 16, 16, 128)  73728       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 16, 16, 128)  512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 16, 16, 128)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 16, 16, 128)  8192        activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 16, 16, 128)  147456      activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 16, 16, 128)  512         conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 16, 16, 128)  512         conv2d_48[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 16, 16, 128)  0           batch_normalization_46[0][0]
#                                                                  batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 16, 16, 128)  0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 16, 16, 128)  147456      activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 16, 16, 128)  512         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 16, 16, 128)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 16, 16, 128)  147456      activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 16, 16, 128)  512         conv2d_50[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 16, 16, 128)  0           activation_41[0][0]
#                                                                  batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 16, 16, 128)  0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 8, 8, 256)    294912      activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 8, 8, 256)    1024        conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 8, 8, 256)    0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 8, 256)    32768       activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 8, 8, 256)    589824      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 8, 8, 256)    1024        conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8, 8, 256)    1024        conv2d_53[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 8, 8, 256)    0           batch_normalization_51[0][0]
#                                                                  batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 8, 8, 256)    0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 8, 8, 256)    589824      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 8, 8, 256)    1024        conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 8, 8, 256)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 8, 256)    589824      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 8, 8, 256)    1024        conv2d_55[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 8, 8, 256)    0           activation_45[0][0]
#                                                                  batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 8, 8, 256)    0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 4, 4, 512)    1179648     activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 4, 4, 512)    2048        conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 4, 4, 512)    0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 4, 4, 512)    131072      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 4, 4, 512)    2359296     activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 4, 4, 512)    2048        conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 4, 4, 512)    2048        conv2d_58[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 4, 4, 512)    0           batch_normalization_56[0][0]
#                                                                  batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 4, 4, 512)    0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 4, 4, 512)    2359296     activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 4, 4, 512)    2048        conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 4, 4, 512)    0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 4, 4, 512)    2359296     activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 4, 4, 512)    2048        conv2d_60[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 4, 4, 512)    0           activation_49[0][0]
#                                                                  batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 4, 4, 512)    0           add_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 1, 512)    0           activation_51[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 512)          0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           5130        flatten_3[0][0]
# ==================================================================================================
# Total params: 11,183,562
# Trainable params: 11,173,962
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %%
plot_model(resnet18, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images

# Compute quantities required for feature-wise normalization
# (std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train)

# %%
# Fit the model on the batches generated by datagen.flow().
history = resnet18.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    validation_data=(x_test, y_test),
                    epochs=nb_epoch, verbose=1, max_q_size=100,
                    callbacks=[ LearningRateScheduler(schedule=schedule)])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., steps_per_epoch=390, validation_data=(array([[[..., epochs=200, verbose=1, callbacks=[<keras.ca..., max_queue_size=100)`
#   """
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/200
# 390/390 [==============================] - 46s 119ms/step - loss: 1.7553 - acc: 0.5060 - val_loss: 3.4772 - val_acc: 0.3741
# Epoch 2/200
# 390/390 [==============================] - 33s 84ms/step - loss: 1.1874 - acc: 0.6850 - val_loss: 1.8748 - val_acc: 0.5518
# Epoch 3/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.9655 - acc: 0.7521 - val_loss: 1.8290 - val_acc: 0.5709
# Epoch 4/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.8605 - acc: 0.7849 - val_loss: 1.3211 - val_acc: 0.6634
# Epoch 5/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.7923 - acc: 0.8087 - val_loss: 0.8855 - val_acc: 0.7876
# Epoch 6/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.7513 - acc: 0.8229 - val_loss: 1.3627 - val_acc: 0.6793
# Epoch 7/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.7225 - acc: 0.8345 - val_loss: 1.0530 - val_acc: 0.7469
# Epoch 8/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.6986 - acc: 0.8450 - val_loss: 0.9025 - val_acc: 0.7921
# Epoch 9/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.6867 - acc: 0.8507 - val_loss: 1.1431 - val_acc: 0.7163
# Epoch 10/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.6611 - acc: 0.8608 - val_loss: 0.7642 - val_acc: 0.8268
# Epoch 11/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.6459 - acc: 0.8670 - val_loss: 1.0033 - val_acc: 0.7443
# Epoch 12/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.6393 - acc: 0.8711 - val_loss: 0.8273 - val_acc: 0.8076
# Epoch 13/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.6181 - acc: 0.8783 - val_loss: 1.0091 - val_acc: 0.7670
# Epoch 14/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.6079 - acc: 0.8813 - val_loss: 0.7765 - val_acc: 0.8255
# Epoch 15/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.5958 - acc: 0.8850 - val_loss: 1.0959 - val_acc: 0.7535
# Epoch 16/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.5861 - acc: 0.8906 - val_loss: 1.0415 - val_acc: 0.7557
# Epoch 17/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.5814 - acc: 0.8949 - val_loss: 0.9497 - val_acc: 0.7914
# Epoch 18/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.5660 - acc: 0.8969 - val_loss: 0.7551 - val_acc: 0.8385
# Epoch 19/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.5610 - acc: 0.9003 - val_loss: 0.7928 - val_acc: 0.8284
# Epoch 20/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.5530 - acc: 0.9023 - val_loss: 0.7557 - val_acc: 0.8406
# Epoch 21/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.5403 - acc: 0.9069 - val_loss: 0.6856 - val_acc: 0.8605
# Epoch 22/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.5428 - acc: 0.9075 - val_loss: 0.9400 - val_acc: 0.8024
# Epoch 23/200
# 390/390 [==============================] - 34s 87ms/step - loss: 0.5270 - acc: 0.9096 - val_loss: 0.7859 - val_acc: 0.8324
# Epoch 24/200
# 390/390 [==============================] - 34s 86ms/step - loss: 0.5202 - acc: 0.9126 - val_loss: 0.8105 - val_acc: 0.8367
# Epoch 25/200
# 390/390 [==============================] - 34s 86ms/step - loss: 0.5193 - acc: 0.9128 - val_loss: 0.7657 - val_acc: 0.8507
# Epoch 26/200
# 390/390 [==============================] - 34s 87ms/step - loss: 0.5057 - acc: 0.9165 - val_loss: 0.7564 - val_acc: 0.8501
# Epoch 27/200
# 390/390 [==============================] - 34s 86ms/step - loss: 0.5039 - acc: 0.9171 - val_loss: 0.9233 - val_acc: 0.8143
# Epoch 28/200
# 390/390 [==============================] - 33s 83ms/step - loss: 0.4990 - acc: 0.9218 - val_loss: 0.6716 - val_acc: 0.8705
# Epoch 29/200
# 390/390 [==============================] - 33s 86ms/step - loss: 0.5007 - acc: 0.9210 - val_loss: 0.7191 - val_acc: 0.8596
# Epoch 30/200
# 390/390 [==============================] - 33s 86ms/step - loss: 0.4887 - acc: 0.9222 - val_loss: 0.7444 - val_acc: 0.8547
# Epoch 31/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.4898 - acc: 0.9229 - val_loss: 0.6895 - val_acc: 0.8659
# Epoch 32/200
# 390/390 [==============================] - 34s 86ms/step - loss: 0.4778 - acc: 0.9257 - val_loss: 1.1026 - val_acc: 0.7760
# Epoch 33/200
# 390/390 [==============================] - 34s 86ms/step - loss: 0.4753 - acc: 0.9267 - val_loss: 0.7198 - val_acc: 0.8591
# Epoch 34/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.4782 - acc: 0.9253 - val_loss: 9.6514 - val_acc: 0.3080
# Epoch 35/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.4942 - acc: 0.9243 - val_loss: 1.1308 - val_acc: 0.8029
# Epoch 36/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.4677 - acc: 0.9296 - val_loss: 0.6856 - val_acc: 0.8647
# Epoch 37/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.4643 - acc: 0.9291 - val_loss: 0.7173 - val_acc: 0.8613
# Epoch 38/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.4517 - acc: 0.9330 - val_loss: 0.6719 - val_acc: 0.8772
# Epoch 39/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.4482 - acc: 0.9326 - val_loss: 0.9350 - val_acc: 0.8240
# Epoch 40/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.3764 - acc: 0.9586 - val_loss: 0.4906 - val_acc: 0.9235
# Epoch 41/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.3360 - acc: 0.9694 - val_loss: 0.4877 - val_acc: 0.9214
# Epoch 42/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.3196 - acc: 0.9727 - val_loss: 0.4690 - val_acc: 0.9272
# Epoch 43/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.2995 - acc: 0.9764 - val_loss: 0.4747 - val_acc: 0.9251
# Epoch 44/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.2901 - acc: 0.9782 - val_loss: 0.4671 - val_acc: 0.9273
# Epoch 45/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.2783 - acc: 0.9795 - val_loss: 0.4685 - val_acc: 0.9285
# Epoch 46/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.2676 - acc: 0.9814 - val_loss: 0.4675 - val_acc: 0.9263
# Epoch 47/200
# 390/390 [==============================] - 33s 83ms/step - loss: 0.2584 - acc: 0.9839 - val_loss: 0.4827 - val_acc: 0.9242
# Epoch 48/200
# 390/390 [==============================] - 33s 83ms/step - loss: 0.2512 - acc: 0.9845 - val_loss: 0.4697 - val_acc: 0.9287
# Epoch 49/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.2454 - acc: 0.9852 - val_loss: 0.4625 - val_acc: 0.9278
# Epoch 50/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.2382 - acc: 0.9863 - val_loss: 0.4647 - val_acc: 0.9279
# Epoch 51/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.2305 - acc: 0.9874 - val_loss: 0.4757 - val_acc: 0.9309
# Epoch 52/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.2244 - acc: 0.9879 - val_loss: 0.4803 - val_acc: 0.9290
# Epoch 53/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.2190 - acc: 0.9889 - val_loss: 0.4887 - val_acc: 0.9276
# Epoch 54/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.2156 - acc: 0.9889 - val_loss: 0.4888 - val_acc: 0.9261
# Epoch 55/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.2094 - acc: 0.9903 - val_loss: 0.4851 - val_acc: 0.9284
# Epoch 56/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.2050 - acc: 0.9911 - val_loss: 0.4807 - val_acc: 0.9281
# Epoch 57/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.2025 - acc: 0.9905 - val_loss: 0.4629 - val_acc: 0.9322
# Epoch 58/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1998 - acc: 0.9906 - val_loss: 0.4703 - val_acc: 0.9282
# Epoch 59/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1937 - acc: 0.9913 - val_loss: 0.4779 - val_acc: 0.9282
# Epoch 60/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.4708 - acc: 0.9122 - val_loss: 0.7360 - val_acc: 0.8484
# Epoch 61/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.4327 - acc: 0.9284 - val_loss: 0.8286 - val_acc: 0.8247
# Epoch 62/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.4251 - acc: 0.9329 - val_loss: 0.6608 - val_acc: 0.8716
# Epoch 63/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.4246 - acc: 0.9347 - val_loss: 0.7536 - val_acc: 0.8454
# Epoch 64/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.4183 - acc: 0.9361 - val_loss: 0.6102 - val_acc: 0.8839
# Epoch 65/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.4123 - acc: 0.9391 - val_loss: 0.6206 - val_acc: 0.8817
# Epoch 66/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.4283 - acc: 0.9365 - val_loss: 0.7632 - val_acc: 0.8513
# Epoch 67/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.4216 - acc: 0.9374 - val_loss: 0.6778 - val_acc: 0.8747
# Epoch 68/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.4134 - acc: 0.9404 - val_loss: 0.7157 - val_acc: 0.8593
# Epoch 69/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.4130 - acc: 0.9410 - val_loss: 0.6618 - val_acc: 0.8740
# Epoch 70/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.3450 - acc: 0.9647 - val_loss: 0.4918 - val_acc: 0.9201
# Epoch 71/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.3118 - acc: 0.9746 - val_loss: 0.4759 - val_acc: 0.9248
# Epoch 72/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.2960 - acc: 0.9773 - val_loss: 0.4811 - val_acc: 0.9235
# Epoch 73/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.2804 - acc: 0.9811 - val_loss: 0.4708 - val_acc: 0.9272
# Epoch 74/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.2706 - acc: 0.9828 - val_loss: 0.4655 - val_acc: 0.9251
# Epoch 75/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.2602 - acc: 0.9842 - val_loss: 0.4803 - val_acc: 0.9250
# Epoch 76/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.2521 - acc: 0.9857 - val_loss: 0.4865 - val_acc: 0.9237
# Epoch 77/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.2431 - acc: 0.9868 - val_loss: 0.4810 - val_acc: 0.9268
# Epoch 78/200
# 390/390 [==============================] - 33s 86ms/step - loss: 0.2364 - acc: 0.9875 - val_loss: 0.4854 - val_acc: 0.9267
# Epoch 79/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.2293 - acc: 0.9887 - val_loss: 0.4787 - val_acc: 0.9300
# Epoch 80/200
# 390/390 [==============================] - 33s 86ms/step - loss: 0.2237 - acc: 0.9893 - val_loss: 0.4701 - val_acc: 0.9273
# Epoch 81/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.2164 - acc: 0.9907 - val_loss: 0.4870 - val_acc: 0.9242
# Epoch 82/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.2133 - acc: 0.9907 - val_loss: 0.4681 - val_acc: 0.9285
# Epoch 83/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.2074 - acc: 0.9913 - val_loss: 0.4887 - val_acc: 0.9259
# Epoch 84/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.2035 - acc: 0.9914 - val_loss: 0.4756 - val_acc: 0.9269
# Epoch 85/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1977 - acc: 0.9922 - val_loss: 0.4676 - val_acc: 0.9307
# Epoch 86/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1964 - acc: 0.9917 - val_loss: 0.4939 - val_acc: 0.9247
# Epoch 87/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1923 - acc: 0.9925 - val_loss: 0.4769 - val_acc: 0.9275
# Epoch 88/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1883 - acc: 0.9927 - val_loss: 0.4948 - val_acc: 0.9254
# Epoch 89/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1836 - acc: 0.9936 - val_loss: 0.4714 - val_acc: 0.9294
# Epoch 90/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1806 - acc: 0.9934 - val_loss: 0.4879 - val_acc: 0.9254
# Epoch 91/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1799 - acc: 0.9929 - val_loss: 0.4711 - val_acc: 0.9294
# Epoch 92/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1752 - acc: 0.9938 - val_loss: 0.4751 - val_acc: 0.9268
# Epoch 93/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.1725 - acc: 0.9939 - val_loss: 0.4927 - val_acc: 0.9247
# Epoch 94/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1682 - acc: 0.9945 - val_loss: 0.4967 - val_acc: 0.9249
# Epoch 95/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1665 - acc: 0.9943 - val_loss: 0.5206 - val_acc: 0.9252
# Epoch 96/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1648 - acc: 0.9940 - val_loss: 0.5067 - val_acc: 0.9205
# Epoch 97/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1616 - acc: 0.9947 - val_loss: 0.4864 - val_acc: 0.9293
# Epoch 98/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1595 - acc: 0.9947 - val_loss: 0.4819 - val_acc: 0.9262
# Epoch 99/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1562 - acc: 0.9952 - val_loss: 0.4770 - val_acc: 0.9296
# Epoch 100/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1546 - acc: 0.9952 - val_loss: 0.4861 - val_acc: 0.9302
# Epoch 101/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1536 - acc: 0.9945 - val_loss: 0.4983 - val_acc: 0.9243
# Epoch 102/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.1513 - acc: 0.9948 - val_loss: 0.4853 - val_acc: 0.9282
# Epoch 103/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1490 - acc: 0.9950 - val_loss: 0.5211 - val_acc: 0.9214
# Epoch 104/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1486 - acc: 0.9943 - val_loss: 0.4820 - val_acc: 0.9254
# Epoch 105/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1433 - acc: 0.9959 - val_loss: 0.4841 - val_acc: 0.9275
# Epoch 106/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1447 - acc: 0.9945 - val_loss: 0.4811 - val_acc: 0.9243
# Epoch 107/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1434 - acc: 0.9945 - val_loss: 0.4805 - val_acc: 0.9277
# Epoch 108/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1399 - acc: 0.9954 - val_loss: 0.4666 - val_acc: 0.9329
# Epoch 109/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1391 - acc: 0.9952 - val_loss: 0.4937 - val_acc: 0.9263
# Epoch 110/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1358 - acc: 0.9958 - val_loss: 0.4711 - val_acc: 0.9285
# Epoch 111/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.1342 - acc: 0.9960 - val_loss: 0.4988 - val_acc: 0.9238
# Epoch 112/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.1342 - acc: 0.9950 - val_loss: 0.4856 - val_acc: 0.9271
# Epoch 113/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.1334 - acc: 0.9953 - val_loss: 0.4998 - val_acc: 0.9274
# Epoch 114/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.1320 - acc: 0.9953 - val_loss: 0.4906 - val_acc: 0.9202
# Epoch 115/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.1289 - acc: 0.9953 - val_loss: 0.4772 - val_acc: 0.9281
# Epoch 116/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1290 - acc: 0.9951 - val_loss: 0.4891 - val_acc: 0.9251
# Epoch 117/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1273 - acc: 0.9952 - val_loss: 0.4902 - val_acc: 0.9243
# Epoch 118/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1260 - acc: 0.9955 - val_loss: 0.4718 - val_acc: 0.9263
# Epoch 119/200
# 390/390 [==============================] - 33s 83ms/step - loss: 0.1243 - acc: 0.9954 - val_loss: 0.4771 - val_acc: 0.9270
# Epoch 120/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1249 - acc: 0.9950 - val_loss: 0.4769 - val_acc: 0.9268
# Epoch 121/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1221 - acc: 0.9954 - val_loss: 0.4730 - val_acc: 0.9289
# Epoch 122/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1205 - acc: 0.9958 - val_loss: 0.4788 - val_acc: 0.9273
# Epoch 123/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1203 - acc: 0.9957 - val_loss: 0.4789 - val_acc: 0.9261
# Epoch 124/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1194 - acc: 0.9955 - val_loss: 0.5012 - val_acc: 0.9208
# Epoch 125/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1169 - acc: 0.9962 - val_loss: 0.4802 - val_acc: 0.9230
# Epoch 126/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1187 - acc: 0.9950 - val_loss: 0.5051 - val_acc: 0.9201
# Epoch 127/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1150 - acc: 0.9958 - val_loss: 0.4804 - val_acc: 0.9266
# Epoch 128/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1146 - acc: 0.9959 - val_loss: 0.4666 - val_acc: 0.9276
# Epoch 129/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1145 - acc: 0.9954 - val_loss: 0.4976 - val_acc: 0.9231
# Epoch 130/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1138 - acc: 0.9958 - val_loss: 0.4803 - val_acc: 0.9263
# Epoch 131/200
# 390/390 [==============================] - 34s 87ms/step - loss: 0.1132 - acc: 0.9955 - val_loss: 0.4666 - val_acc: 0.9271
# Epoch 132/200
# 390/390 [==============================] - 34s 86ms/step - loss: 0.1110 - acc: 0.9960 - val_loss: 0.4741 - val_acc: 0.9256
# Epoch 133/200
# 390/390 [==============================] - 34s 87ms/step - loss: 0.1098 - acc: 0.9959 - val_loss: 0.4906 - val_acc: 0.9229
# Epoch 134/200
# 390/390 [==============================] - 34s 86ms/step - loss: 0.1114 - acc: 0.9952 - val_loss: 0.4837 - val_acc: 0.9253
# Epoch 135/200
# 390/390 [==============================] - 33s 86ms/step - loss: 0.1091 - acc: 0.9956 - val_loss: 0.4861 - val_acc: 0.9252
# Epoch 136/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1077 - acc: 0.9955 - val_loss: 0.4737 - val_acc: 0.9281
# Epoch 137/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1089 - acc: 0.9951 - val_loss: 0.4743 - val_acc: 0.9251
# Epoch 138/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1060 - acc: 0.9961 - val_loss: 0.4757 - val_acc: 0.9268
# Epoch 139/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1061 - acc: 0.9959 - val_loss: 0.4755 - val_acc: 0.9272
# Epoch 140/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1065 - acc: 0.9953 - val_loss: 0.4466 - val_acc: 0.9289
# Epoch 141/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1039 - acc: 0.9960 - val_loss: 0.4532 - val_acc: 0.9285
# Epoch 142/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1054 - acc: 0.9952 - val_loss: 0.4568 - val_acc: 0.9275
# Epoch 143/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1021 - acc: 0.9961 - val_loss: 0.4540 - val_acc: 0.9288
# Epoch 144/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1024 - acc: 0.9960 - val_loss: 0.4829 - val_acc: 0.9253
# Epoch 145/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.1002 - acc: 0.9963 - val_loss: 0.4882 - val_acc: 0.9264
# Epoch 146/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1010 - acc: 0.9959 - val_loss: 0.4778 - val_acc: 0.9262
# Epoch 147/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1016 - acc: 0.9956 - val_loss: 0.4511 - val_acc: 0.9265
# Epoch 148/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1023 - acc: 0.9951 - val_loss: 0.5945 - val_acc: 0.9105
# Epoch 149/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1013 - acc: 0.9950 - val_loss: 0.4769 - val_acc: 0.9266
# Epoch 150/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.1001 - acc: 0.9954 - val_loss: 0.4651 - val_acc: 0.9262
# Epoch 151/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0980 - acc: 0.9962 - val_loss: 0.4763 - val_acc: 0.9262
# Epoch 152/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.0963 - acc: 0.9965 - val_loss: 0.4762 - val_acc: 0.9242
# Epoch 153/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.0968 - acc: 0.9963 - val_loss: 0.4780 - val_acc: 0.9257
# Epoch 154/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0959 - acc: 0.9962 - val_loss: 0.4911 - val_acc: 0.9254
# Epoch 155/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.0965 - acc: 0.9953 - val_loss: 0.4624 - val_acc: 0.9285
# Epoch 156/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0949 - acc: 0.9958 - val_loss: 0.4574 - val_acc: 0.9292
# Epoch 157/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.0961 - acc: 0.9955 - val_loss: 0.5018 - val_acc: 0.9211
# Epoch 158/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0946 - acc: 0.9960 - val_loss: 0.4771 - val_acc: 0.9249
# Epoch 159/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.0943 - acc: 0.9952 - val_loss: 0.4813 - val_acc: 0.9237
# Epoch 160/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0950 - acc: 0.9953 - val_loss: 0.4832 - val_acc: 0.9242
# Epoch 161/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0933 - acc: 0.9959 - val_loss: 0.5022 - val_acc: 0.9229
# Epoch 162/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.0923 - acc: 0.9961 - val_loss: 0.4776 - val_acc: 0.9268
# Epoch 163/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.0935 - acc: 0.9954 - val_loss: 0.4557 - val_acc: 0.9262
# Epoch 164/200
# 390/390 [==============================] - 33s 83ms/step - loss: 0.0918 - acc: 0.9960 - val_loss: 0.4753 - val_acc: 0.9245
# Epoch 165/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0909 - acc: 0.9959 - val_loss: 0.5004 - val_acc: 0.9229
# Epoch 166/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0896 - acc: 0.9961 - val_loss: 0.4795 - val_acc: 0.9257
# Epoch 167/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0919 - acc: 0.9951 - val_loss: 0.5103 - val_acc: 0.9188
# Epoch 168/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0898 - acc: 0.9960 - val_loss: 0.4760 - val_acc: 0.9227
# Epoch 169/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.0888 - acc: 0.9963 - val_loss: 0.4688 - val_acc: 0.9254
# Epoch 170/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.0901 - acc: 0.9955 - val_loss: 0.4933 - val_acc: 0.9233
# Epoch 171/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.0895 - acc: 0.9956 - val_loss: 0.4704 - val_acc: 0.9248
# Epoch 172/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.0878 - acc: 0.9961 - val_loss: 0.4615 - val_acc: 0.9274
# Epoch 173/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.0874 - acc: 0.9961 - val_loss: 0.4822 - val_acc: 0.9240
# Epoch 174/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0877 - acc: 0.9956 - val_loss: 0.4934 - val_acc: 0.9246
# Epoch 175/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0868 - acc: 0.9958 - val_loss: 0.4831 - val_acc: 0.9220
# Epoch 176/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0878 - acc: 0.9954 - val_loss: 0.4793 - val_acc: 0.9254
# Epoch 177/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0852 - acc: 0.9965 - val_loss: 0.4466 - val_acc: 0.9281
# Epoch 178/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0851 - acc: 0.9961 - val_loss: 0.4638 - val_acc: 0.9280
# Epoch 179/200
# 390/390 [==============================] - 33s 84ms/step - loss: 0.0870 - acc: 0.9952 - val_loss: 0.4746 - val_acc: 0.9279
# Epoch 180/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0863 - acc: 0.9954 - val_loss: 0.4627 - val_acc: 0.9250
# Epoch 181/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0869 - acc: 0.9950 - val_loss: 0.4881 - val_acc: 0.9207
# Epoch 182/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0845 - acc: 0.9958 - val_loss: 0.4936 - val_acc: 0.9207
# Epoch 183/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0854 - acc: 0.9954 - val_loss: 0.4685 - val_acc: 0.9275
# Epoch 184/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0846 - acc: 0.9956 - val_loss: 0.4870 - val_acc: 0.9233
# Epoch 185/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0833 - acc: 0.9959 - val_loss: 0.4995 - val_acc: 0.9247
# Epoch 186/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.0832 - acc: 0.9960 - val_loss: 0.4761 - val_acc: 0.9239
# Epoch 187/200
# 390/390 [==============================] - 33s 85ms/step - loss: 0.0847 - acc: 0.9954 - val_loss: 0.4922 - val_acc: 0.9251
# Epoch 188/200
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0819 - acc: 0.9963 - val_loss: 0.4670 - val_acc: 0.9251
# Epoch 189/200
# 390/390 [==============================] - 34s 86ms/step - loss: 0.0826 - acc: 0.9957 - val_loss: 0.5512 - val_acc: 0.9162
# Epoch 190/200
# 390/390 [==============================] - 34s 86ms/step - loss: 0.0828 - acc: 0.9956 - val_loss: 0.5188 - val_acc: 0.9216
# Epoch 191/200
# 390/390 [==============================] - 33s 86ms/step - loss: 0.0817 - acc: 0.9960 - val_loss: 0.4653 - val_acc: 0.9237
# Epoch 192/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0827 - acc: 0.9954 - val_loss: 0.4602 - val_acc: 0.9248
# Epoch 193/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.0816 - acc: 0.9957 - val_loss: 0.4918 - val_acc: 0.9242
# Epoch 194/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.0831 - acc: 0.9952 - val_loss: 0.4798 - val_acc: 0.9235
# Epoch 195/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.0819 - acc: 0.9954 - val_loss: 0.4974 - val_acc: 0.9232
# Epoch 196/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0812 - acc: 0.9958 - val_loss: 0.5045 - val_acc: 0.9243
# Epoch 197/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0797 - acc: 0.9965 - val_loss: 0.4639 - val_acc: 0.9253
# Epoch 198/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0806 - acc: 0.9960 - val_loss: 0.4898 - val_acc: 0.9215
# Epoch 199/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0795 - acc: 0.9964 - val_loss: 0.4907 - val_acc: 0.9215
# Epoch 200/200
# 390/390 [==============================] - 32s 83ms/step - loss: 0.0795 - acc: 0.9959 - val_loss: 0.4788 - val_acc: 0.9228

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
score = resnet18.evaluate(x_test,y_test,verbose=0)
print('Test loss:',score[0])
print('Test accuracy:',score[1])
# Out:
# Test loss: 0.4788119124174118
# Test accuracy: 0.9228
